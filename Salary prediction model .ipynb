# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('adult.csv')

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')#sure no null values
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
#missing values found in form of ?

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
# 1836 missing values

# %%
df['education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df['education-num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
df['education-num'].value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: education-num, dtype: int64

# %%
#we can directly drop education ,since education num also tells same thing

# %%
df.drop('education',axis=1,inplace=True)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0   39          State-gov   77516             13        Never-married
# 1   50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2   38            Private  215646              9             Divorced
# 3   53            Private  234721              7   Married-civ-spouse
# 4   28            Private  338409             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week         country  salary
# 0             0              40   United-States   <=50K
# ...

# %%
df['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
#missing values found in occupation with number 1843

# %%
df['relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64

# %%
df['race'].value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
df['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
df['capital-gain'].value_counts()# numerical feature
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: capital-gain, Length: 119, dtype: int64

# %%
df['capital-loss'].value_counts()
# Out:
# 0       31042
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: capital-loss, Length: 92, dtype: int64

# %%
df['hours-per-week'].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 82        1
# 92        1
# 87        1
# 74        1
# 94        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
df['country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
#missing values in country

# %%
df['salary'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: salary, dtype: int64

# %% [markdown]
# ### handling missing values

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0   39          State-gov   77516             13        Never-married
# 1   50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2   38            Private  215646              9             Divorced
# 3   53            Private  234721              7   Married-civ-spouse
# 4   28            Private  338409             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week         country  salary
# 0             0              40   United-States   <=50K
# ...

# %%
df['country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
df['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df.shape
# Out:
# (32561, 14)

# %%
df['workclass']=df['workclass'].replace(' ?',np.nan)

# %%
df['occupation']=df['occupation'].replace(' ?',np.nan)

# %%
df['country']=df['country'].replace(' ?',np.nan)

# %%
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
df['country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
# United-States                    583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# now we can remove null value rows

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#no null values now

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0   39          State-gov   77516             13        Never-married
# 1   50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2   38            Private  215646              9             Divorced
# 3   53            Private  234721              7   Married-civ-spouse
# 4   28            Private  338409             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week         country  salary
# 0             0              40   United-States   <=50K
# ...

# %% [markdown]
# ### Data visualization

# %%
sns.distplot(df['age'],kde=False,bins=30)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.pairplot(df)

# %%
sns.barplot(x='race',y='age',data=df)
# Out:
# <AxesSubplot:xlabel='race', ylabel='age'>

# %%
sns.countplot(x='race',data=df)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
sns.countplot(x='sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='salary',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
sns.boxplot(x='salary',y='age',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0   39          State-gov   77516             13        Never-married
# 1   50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2   38            Private  215646              9             Divorced
# 3   53            Private  234721              7   Married-civ-spouse
# 4   28            Private  338409             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week         country  salary
# 0             0              40   United-States   <=50K
# ...

# %%
plt.figure(figsize=(10,10))

ax=df.country.value_counts()
ax.plot(kind='pie',fontsize=20)

plt.title('number of countries',fontsize=30,color='darkblue')
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=df.relationship.value_counts()
ax.plot(kind='pie',fontsize=20)

plt.title('number of countries',fontsize=30,color='darkblue')
plt.show()

# %% [markdown]
# ### next

# %%
df.shape
# Out:
# (30718, 14)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt  education-num       marital-status  \
# 0   39          State-gov   77516             13        Never-married
# 1   50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 2   38            Private  215646              9             Divorced
# 3   53            Private  234721              7   Married-civ-spouse
# 4   28            Private  338409             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week         country  salary
# 0             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30718 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30718 non-null  int64
#  1   workclass       30718 non-null  object
#  2   fnlwgt          30718 non-null  int64
#  3   education-num   30718 non-null  int64
#  4   marital-status  30718 non-null  object
#  5   occupation      30718 non-null  object
#  6   relationship    30718 non-null  object
#  7   race            30718 non-null  object
#  8   sex             30718 non-null  object
#  9   capital-gain    30718 non-null  int64
#  10  capital-loss    30718 non-null  int64
#  11  hours-per-week  30718 non-null  int64
#  12  country         30718 non-null  object
#  13  salary          30718 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 4.5+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
list1=['marital-status','occupation','relationship','race','sex','country','salary','workclass']
for i in list1:
    df[i]=le.fit_transform(df[i])

df.head()
# Out:
#    age  workclass  fnlwgt  education-num  marital-status  occupation  \
# 0   39          5   77516             13               4           0
# 1   50          4   83311             13               2           3
# 2   38          2  215646              9               0           5
# 3   53          2  234721              7               2           5
# 4   28          2  338409             13               2           9
#
#    relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0             1     4    1          2174             0              40
# 1             0     4    1             0             0              13
# 2             1     4    1             0             0              40
# 3             0     2    1             0             0              40
# 4             5     2    0             0             0              40
#
#    country  salary
# 0       38       0
# 1       38       0
# 2       38       0
# 3       38       0
# 4        4       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30718 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30718 non-null  int64
#  1   workclass       30718 non-null  int32
#  2   fnlwgt          30718 non-null  int64
#  3   education-num   30718 non-null  int64
#  4   marital-status  30718 non-null  int64
#  5   occupation      30718 non-null  int64
#  6   relationship    30718 non-null  int64
#  7   race            30718 non-null  int64
#  8   sex             30718 non-null  int64
#  9   capital-gain    30718 non-null  int64
#  10  capital-loss    30718 non-null  int64
#  11  hours-per-week  30718 non-null  int64
#  12  country         30718 non-null  int64
#  13  salary          30718 non-null  int64
# dtypes: int32(1), int64(13)
# memory usage: 4.4 MB

# %% [markdown]
# ### ML model

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('salary',axis=1)

# %%
y=df['salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rd = RandomForestClassifier(n_estimators=400)

# %%
rd.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=400)

# %%
pred = rd.predict(X_test)

# %%
pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      7586
#            1       0.76      0.63      0.69      2551
#
#     accuracy                           0.86     10137
#    macro avg       0.82      0.78      0.80     10137
# weighted avg       0.85      0.86      0.85     10137

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[7072  514]
#  [ 948 1603]]
